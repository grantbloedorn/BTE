# %% [markdown]
# <a href="https://colab.research.google.com/github/grantbloedorn/BTE/blob/main/Recursive_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def reverse(s):
    if s == "":
        return s
    return reverse(s[1:]) + s[0]

print(reverse(input("Enter a string: ")))
# Out:
# Enter a string: 1,2,3,4,5
# 5,4,3,2,1
