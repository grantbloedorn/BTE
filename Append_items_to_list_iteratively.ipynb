# %% [markdown]
# <a href="https://colab.research.google.com/github/grantbloedorn/BTE/blob/main/Append_items_to_list_iteratively.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = []
x = float(input("Enter a number (0 to stop): "))

while x != 0:
    nums.append(x)
    x = float(input("Enter a number (0 to stop): "))

nums.sort(reverse=True)
print(nums)
# Out:
# Enter a number (0 to stop): 5
# Enter a number (0 to stop): 3
# Enter a number (0 to stop): 7
# Enter a number (0 to stop): 2
# Enter a number (0 to stop): 9
# Enter a number (0 to stop): 0
# [9.0, 7.0, 5.0, 3.0, 2.0]
