# %% [markdown]
# <a href="https://colab.research.google.com/github/grantbloedorn/BTE/blob/main/Product_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
prices = {
    "P-01": 9.95,
    "P-02": 10.50
}

pid = input("Enter product ID: ")

if pid in prices:
    print(pid, prices[pid])
else:
    print(pid, "not found")
# Out:
# Enter product ID: P-01
# P-01 9.95
